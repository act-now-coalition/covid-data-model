# %%
# %load_ext autoreload
# %autoreload 2
import scipy
import numpy as np
from scipy import stats
from pyseir.cdc.output_mapper import OutputMapper, run_all as run_om
from pyseir.cdc.plots import run_all as run_plots
import matplotlib.pyplot as plt
import pandas as pd
from datetime import timedelta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
om = OutputMapper(fips='05')

# %%
results = om.run()
# Out:
# /anaconda3/envs/pyseir/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2003: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /anaconda3/envs/pyseir/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2004: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
results[results['target'].str.contains('day ahead inc death')]
# Out:
#            forecast_date location location_name                  target  \
# 2020-05-22    2020-05-21       05      Arkansas   1 day ahead inc death
# 2020-05-22    2020-05-21       05      Arkansas   1 day ahead inc death
# 2020-05-22    2020-05-21       05      Arkansas   1 day ahead inc death
# 2020-05-22    2020-05-21       05      Arkansas   1 day ahead inc death
# 2020-05-22    2020-05-21       05      Arkansas   1 day ahead inc death
# ...                  ...      ...           ...                     ...
# 2020-06-16    2020-05-21       05      Arkansas  26 day ahead inc death
# 2020-06-17    2020-05-21       05      Arkansas  27 day ahead inc death
# 2020-06-18    2020-05-21       05      Arkansas  28 day ahead inc death
# 2020-06-19    2020-05-21       05      Arkansas  29 day ahead inc death
# 2020-06-20    2020-05-21       05      Arkansas  30 day ahead inc death
#
#            target_end_date      type quantile     value
# 2020-05-22      2020-05-22  quantile    0.010         0
# 2020-05-22      2020-05-22  quantile    0.025         0
# 2020-05-22      2020-05-22  quantile    0.050  0.353958
# 2020-05-22      2020-05-22  quantile    0.100  0.844083
# 2020-05-22      2020-05-22  quantile    0.150   1.17477
# ...                    ...       ...      ...       ...
# 2020-06-16      2020-06-16     point      nan   2.29807
# 2020-06-17      2020-06-17     point      nan   2.28693
# 2020-06-18      2020-06-18     point      nan   2.27579
# 2020-06-19      2020-06-19     point      nan   2.26465
# 2020-06-20      2020-06-20     point      nan   2.25349
#
# [690 rows x 8 columns]

# %%
run_om()
# Out:
# /anaconda3/envs/pyseir/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2003: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /anaconda3/envs/pyseir/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2004: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
run_plots()
# Out:
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['quantile'] = sub_df['quantile'].apply(lambda x: float(x))
# /Users/xzhang/Documents/covid/covid-data-model/pyseir/cdc/plots.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['pdf'] = np.append(sub_df['quantile'].values[0], np.diff(sub_df['quantile']))
